# %%
import sys
sys.path.append("/home/jupyter-hai/python-workspace/")

# %%
import numpy as np
import matplotlib.pyplot as plt
import streamecg
# %matplotlib notebook

# %%
awshost = "a209xbcpyxq5au-ats.iot.ap-southeast-1.amazonaws.com"
awsport = 8883
clientID = "testDevice"
thingName = "Test-thing"
caPath = "./../../cerfiticates/root.pem"
certPath = "./../../cerfiticates/90dd0acc83-certificate.pem.crt"
keyPath = "./../../cerfiticates/90dd0acc83-private.pem.key"
topic = "test/testing1"
chunkSize = 500

# %%
draw1 = streamecg.Draw(figsize=(10,5),sharey=True)
draw2  = streamecg.Draw(figsize=(10,5),sharey=True,nrows=1,ncols=1)
draw3 = streamecg.Draw(figsize=(10,5),sharey=True,nrows=1,ncols=1,ymin=30,ymax=240)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
subscriber = streamecg.SimpleMQTTSubscriber(awshost=awshost,awsport=awsport,clienID=clientID,thingName=thingName,
                                            caPath=caPath,topic=topic,draw=[draw1,draw2,draw3],certPath=certPath,keyPath=keyPath,
                                            chunkSize=chunkSize,bufferLengthInSecond=10,estimateHeartRate=True)

# %%
subscriber.receive_data()
# Out:
# Connection returned result: 0
# topic: test/testing1
# receive message 0
# /home/jupyter-hai/python-workspace/biorithmfhrpython/src/common/femom_developing_algorithms.py:839: RuntimeWarning: divide by zero encountered in log
#   cepstrum = np.real(np.fft.ifft(np.log(np.abs(np.fft.fft(ecgHF,self.NFFT,axis=0))),axis=0))
# heart rate 150.0
# topic: test/testing1
# receive message 1
# heart rate 44.576523031203564
# topic: test/testing1
# receive message 2
# heart rate 99.00990099009901
# topic: test/testing1
# receive message 3
# heart rate 67.11409395973155
# topic: test/testing1
# receive message 4
# heart rate 66.66666666666667
# topic: test/testing1
# receive message 5
# heart rate 66.66666666666667
# topic: test/testing1
# receive message 6
# heart rate 66.66666666666667
# topic: test/testing1
# receive message 7
# heart rate 67.11409395973155
# topic: test/testing1
# receive message 8
# heart rate 67.26457399103138
# topic: test/testing1
# receive message 9
# ...
