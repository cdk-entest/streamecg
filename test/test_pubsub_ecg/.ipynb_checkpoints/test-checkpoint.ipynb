# %%
import sys
sys.path.ex

# %%
# %matplotlib notebook
import paho.mqtt.client as mqtt
import ssl
import sys
import numpy as np
import matplotlib.pyplot as plt
import

# %%
draw = liveplot.Draw(figsize=(10,5), sharey=True)
draw.axes[0].set_ylim(-32768,32768)
draw.fig
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
subscriber = test_subscribe.SimpleMQTTSubscriber(draw=draw)

# %%
subscriber.receive_data()
# Out:
# Connection returned result: 0
# topic: test/testing1
# receive message 0
# topic: test/testing1
# receive message 1
# topic: test/testing1
# receive message 2
# topic: test/testing1
# receive message 3
# topic: test/testing1
# receive message 4
# topic: test/testing1
# receive message 5
# topic: test/testing1
# receive message 6
# topic: test/testing1
# receive message 7
# topic: test/testing1
# receive message 8
# topic: test/testing1
# receive message 9
# topic: test/testing1
# receive message 10
# topic: test/testing1
# receive message 11
# topic: test/testing1
# receive message 12
# topic: test/testing1
# receive message 13
# topic: test/testing1
# receive message 14
# topic: test/testing1
# receive message 15
# topic: test/testing1
# receive message 16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-938f3068dda7> in <module>
# ...
